# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
es = [0.019, 0.004, 0.042, 0.013, 0.007, 0.006, 0.013, 0.003, 0.034, 0.004]
plt.hist(es, bins=5, range=(0,0.05))
plt.text(0.03, 3.5, f"Mean={np.mean(es):.3f}")
