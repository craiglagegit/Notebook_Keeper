# %%
# %matplotlib inline
import numpy as np
from rubin_sim.skybrightness import SkyModel
from rubin_scheduler.utils import Site 
import pandas as pd

# %%
# Instantiate the sky model (uses defaults for site)
site = Site('LSST')
sky_model = SkyModel(observatory=site)

# %%
sky_model.set_ra_dec_mjd?

# %%
sky_model.set_ra_dec_mjd(lon=180.0, lat=75.0,
                         mjd=61200.75, degrees=True, az_alt=True)
#wave, spec = sky_model.return_wave_spec()

# %%
# Set specific time (MJD), ra, dec, etc.
mjd = 60000.0
ra = 0.0
dec = -30.0
sm.set_time_now(mjd, ra, dec)

# Get brightness in magnitudes per square arcsecond
# filters: 'u', 'g', 'r', 'i', 'z', 'y'
sky_brightness = sm.return_mags()
print(sky_brightness['r'])
