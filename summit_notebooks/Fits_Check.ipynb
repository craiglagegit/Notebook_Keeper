# %%
from astropy.io import fits
from lsst.resources import ResourcePath

# %%
filename = "s3://butler@rubinobs-raw-lsstcam/LSSTCam/20251020/MC_O_20251020_000155/MC_O_20251020_000155_R22_S11.fits"

# %%
rp = ResourcePath(filename)
with rp.open(mode="rb") as f:
    hdu_list = fits.open(f)

# %%
hdr0 = hdu_list[0].header
for key in hdr0.keys():
    print(key, hdr0[key])

# %%
hdu_list[0].verify('fix')

# %%
hdr0 = hdu_list[0].header
for key in hdr0.keys():
    print(key, hdr0[key])

# %%
filename = "s3://butler@rubinobs-raw-lsstcam/LSSTCam/20251021/MC_O_20251021_000001/MC_O_20251021_000001_R22_S11.fits"

# %%
rp = ResourcePath(filename)
with rp.open(mode="rb") as f:
    hdu_list = fits.open(f)

# %%
hdr0 = hdu_list[0].header
for key in hdr0.keys():
    print(key, hdr0[key])

# %%
filename = "s3://butler@rubinobs-raw-lsstcam/LSSTCam/20250921/MC_O_20250921_000357/MC_O_20250921_000357_R22_S11.fits"

# %%
rp = ResourcePath(filename)
with rp.open(mode="rb") as f:
    hdu_list = fits.open(f)

# %%
hdr0 = hdu_list[0].header
for key in hdr0.keys():
    print(key, hdr0[key])
