# %%
from astropy.time import Time, TimeDelta
from lsst.summit.utils.efdUtils import makeEfdClient, getEfdData

client = makeEfdClient()

dayObs = 20251105
blocks = getEfdData(client, "lsst.sal.ScriptQueue.command_add", dayObs=dayObs)
myBlock = blocks[blocks['block']=='BLOCK-T3']
startBlock = myBlock[myBlock['startBlock']==True]
print(len(startBlock))
print(startBlock.index[0])
